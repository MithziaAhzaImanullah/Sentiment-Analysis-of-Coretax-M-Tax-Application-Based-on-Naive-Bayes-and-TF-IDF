# %%
# !pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.7-py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.7 MB/s eta 0:00:00
# Downloading google_play_scraper-1.2.7-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.7

# %%
# !pip install pandas
# !pip install numpy
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)

# %%
from google_play_scraper import app
import pandas as pd
import numpy as np

# %%
from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
'com.gojek.app',
lang = 'id',
country = 'id',
sort = Sort.NEWEST,
count = 10000,
filter_score_with=None
)

# %%
df_busu = pd.DataFrame(np.array(result), columns = ['review'])
df_busu = df_busu.join(pd.DataFrame(df_busu.pop('review').tolist()))
df_busu.tail()
# Out:
#                                   reviewId             userName  \
# 9995  e55c3930-3de4-4191-9501-02179909866d       Widya Herawati
# 9996  d87c490f-b38d-41b8-b82f-5268566ce6b9  Abdul Salam Ghozali
# 9997  43e11a05-8679-44fc-a42e-c0af466543fb           roy sadega
# 9998  b4ffd813-f511-470b-a520-7672fa11a0a3          Evi Muryani
# 9999  0a54561a-3ffe-4278-944b-089c20bda2aa      Fransiska Utami
#
#                                               userImage  \
# 9995  https://play-lh.googleusercontent.com/a/ACg8oc...
# 9996  https://play-lh.googleusercontent.com/a/ACg8oc...
# 9997  https://play-lh.googleusercontent.com/a/ACg8oc...
# 9998  https://play-lh.googleusercontent.com/a/ACg8oc...
# 9999  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                                 content  score  thumbsUpCount  \
# 9995  tarif sedang sedang aja.driver nya sopan.cuma ...      5              0
# 9996  Gocar tarifnya diluar nurul. Dari BEC ke Cimin...      1              0
# 9997                                      ya lumayanlah      3              0
# 9998  pesen go car buat ke puskesmas, nyantol 4 driv...      3              0
# 9999                                             mantap      5              0
#
#      reviewCreatedVersion                  at  \
# 9995               5.52.1 2026-03-23 00:25:30
# 9996               5.52.1 2026-03-23 00:20:22
# 9997               5.51.1 2026-03-23 00:20:03
# 9998               5.53.2 2026-03-23 00:08:41
# 9999               5.52.1 2026-03-23 00:01:11
#
#                                            replyContent           repliedAt  \
# 9995                                               None                 NaT
# 9996  Mohon maaf atas ketidaknyamanannya, Kak Abdul.... 2026-03-23 01:21:20
# 9997                                               None                 NaT
# 9998  Hai Kak Evi, mohon maaf atas ketidaknyamananny... 2026-03-23 01:19:30
# 9999                                               None                 NaT
#
#      appVersion
# 9995     5.52.1
# 9996     5.52.1
# 9997     5.51.1
# 9998     5.53.2
# 9999     5.52.1

# %%
my_df = df_busu[['userName','score','at','content']]

# %%
my_df.to_csv("DataSetGojek.csv", index = False)
