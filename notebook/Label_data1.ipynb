# %%
# !pip install pandas
# !pip install numpy
# !pip install nltk

# %%
import numpy as np #operasi numerik

import nltk #pengolahan text

import string #manipulasi text

import re #mencari pola kata yang spesifik

import warnings #menghilangkan warning karena migrasi python
warnings.filterwarnings('ignore')

# %%
import pandas as pd
from tqdm import tqdm, notebook
import warnings
warnings.filterwarnings('ignore')

pd.pandas.set_option('display.max_columns', None)
pd.pandas.set_option('display.max_rows', None)
pd.pandas.set_option('display.max_colwidth', None)
pd.pandas.set_option('display.width', None)

# %%
df = pd.read_csv('DataSetM-Pajak.csv')
df.head()
# Out:
#           userName  score                   at  \
# 0  Pengguna Google      1  2026-05-31 15:06:05
# 1  Pengguna Google      2  2026-05-31 13:26:18
# 2  Pengguna Google      1  2026-05-31 12:57:31
# 3  Pengguna Google      1  2026-05-31 10:51:00
# 4  Pengguna Google      5  2026-05-31 00:41:31
#
#                                                                                                                                                                           content
# 0                                                                                                                              parah aplikasi apaan begini,masa Eror Mulu hadeeeh
# 1                                                                                                                                    🙏kartu WNWP Ari Iswanto kok gak idup lagi ya
# ...

# %%
df['sentiment'] = df['score'].map({1.0:0, 2.0:0, 3.0:1, 4.0:1, 5.0:1})

# %%
myData = pd.DataFrame(df[['content', 'sentiment']])
myData.head(10)
# Out:
#                                                                                                                                                                                            content  \
# 0                                                                                                                                               parah aplikasi apaan begini,masa Eror Mulu hadeeeh
# 1                                                                                                                                                     🙏kartu WNWP Ari Iswanto kok gak idup lagi ya
# 2                   Mau log in via aplikasi diarahin ke web coretax wkwkw. udah gitu gabisa di akses 😂. "SITUS TIDAK DAPAT DIJANGKAU". Lucu ya aplikasi pelayanan untuk masyarakat seburuk ini. 👎🏻
# 3                                                                                                                                                                                            ribet
# ...

# %%
my_df = myData[['content', 'sentiment']]

# %%
my_df.to_csv('label_mpajak.csv', index=False)
